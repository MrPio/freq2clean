# %%
import sys

sys.path.append("../../..")
from src import *
# Out:
# Cupy Available= 1

# %%
trainings = Path().glob("*/")
cprint(*[f"rand:{t}" for t in trainings])
# Out:
# synthetic202512221659

# %%
training = "synthetic202512221659"
tiffs = sorted(Path(training).glob("*.tif"))

# %%
imshow({tiff.stem: Recording(tiff).normalized[-1] for tiff in tiffs}, zoom=2)
