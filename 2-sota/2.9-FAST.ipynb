# %%
# %load_ext autoreload
# %autoreload 2
import sys

sys.path.append("..")
from src import *
# Out:
# Cupy Available= 1

# %% [markdown]
# # [FAST](https://github.com/FDU-donglab/FAST)
# FrAme-multiplexed SpatioTemporal Learning Strategy.

# %% [markdown]
# ## Very low input SNR 30HZ
# Here we use the checkpoint (`Pretrained_0.3Hz_50mWpower_1000frames`) provided by the authors.

# %%
frame = 100
max_frames = frame + 1
meta = DATASETS["synthetic"]
x = Recording(meta.x, norm=True, max_frames=max_frames)
y = Recording(meta.dir / "fast.tif", norm=True, max_frames=max_frames)
gt = Recording(meta.gt, norm=True, max_frames=max_frames)
# Out:
# No normalized version for (fast) found on disk. Generating one...

# %%
imshow(
    {
        "Noisy": x.np[frame],
        "FAST": y.np[frame],
        "Ground truth": gt.np[frame],
    },
    size=7,
    zoom=2,
)

# %%
psnr3d(y.np, gt.np), ssim3d(y.np, gt.np)
# Out:
# (np.float64(22.589104375313475), 0.3909546434879303)

# %% [markdown]
# Results are not so good
