# %%
# %load_ext autoreload
# %autoreload 2
import sys
from pathlib import Path
import numpy as np
from scipy.fftpack import dctn, idctn
from tqdm import tqdm
import pandas as pd

sys.path.append(str(Path("..").resolve()))
from src import *

# %% [markdown]
# # Video Editing

# %%
editor = Editor()

# %%
vid1 = "astro_deepcad.mp4"
vid2 = "astro_dct_fused_w512_8_24_0_64.mp4"
editor.alternate(
    {"DeepCAD-RT": vid1, "DCT-Fused": vid2},
    output=f"{Path(vid2).stem}_alternated.mp4",
    delta=2.0,
)
# Out:
# Moviepy - Building video astro_dct_fused_48_128_-6_16_alternated.mp4.
# Moviepy - Writing video astro_dct_fused_48_128_-6_16_alternated.mp4
# Moviepy - Done !
# Moviepy - video ready astro_dct_fused_48_128_-6_16_alternated.mp4
# <video src="astro_dct_fused_48_128_-6_16_alternated.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
vid1 = "astro_deepcad.mp4"
vid2 = "astro_wavelet_fused_w256_db2_l2.mp4"
editor.alternate(
    {"DeepCAD-RT": vid1, "Haar-Fused": vid2},
    output=f"{Path(vid2).stem}_alternated.mp4",
    delta=2.0,
)
# Out:
# Moviepy - Building video astro_wavelet_fused_w256_db2_l2_alternated.mp4.
# Moviepy - Writing video astro_wavelet_fused_w256_db2_l2_alternated.mp4
# Moviepy - Done !
# Moviepy - video ready astro_wavelet_fused_w256_db2_l2_alternated.mp4
# <video src="astro_wavelet_fused_w256_db2_l2_alternated.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
