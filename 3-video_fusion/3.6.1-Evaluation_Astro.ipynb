# %%
# %load_ext autoreload
# %autoreload 2
import sys
from csbdeep.utils import normalize

sys.path.append("..")
from src import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # PSNR and SSIM3D metrics

# %%
dataset = "oabf_resonant_neuro"
FRAMES = 100

# %%
meta = DATASETS[dataset]
x, y = (Recording(_, max_frames=FRAMES) for _ in [meta.x, meta.dir / "y.tiff"])

# %%
fft = Recording(np.load(f"results/{dataset}/ftt_oabf_resonant_neuro_frame3000_alphas0.85deepcad_theirs.npy"))

# %%
ax=pd.Series(fft.np[:FRAMES:10].flatten()).hist(figsize=(16,6),bins=300)
pd.Series(y.np[::10].flatten()).hist(figsize=(16,6),bins=300,ax=ax)
pd.Series(x.np[::10].flatten()).hist(figsize=(16,6),bins=300,ax=ax)
plt.yscale("log")

# %%
series=y.np[:FRAMES,:8].flatten()
series[series>2**16-1_000]=0
# series=np.clip(normalize(series, 0.25, 97), 0, 1)
ax=pd.Series(series).hist(figsize=(16,6),bins=300)
plt.yscale("log")

# %%
from skimage.exposure import match_histograms

fft_frame = match_histograms(fft.np[-1], y.np[-1])
imshow([fft.np[-1], y.np[-1], fft_frame],zoom=2)

# %%
AVG_WIN = 256
voxel_xs = {
    "raw": x.normalized,
    "deep_cad": y.normalized,
    "fft": fft.normalized,
}
voxel_y = x.avg(AVG_WIN).normalized

# Ensure Voxels are in [0,1] to ensure metrics homogeneity
for voxel in [voxel_y, *voxel_xs.values()]:
    assert abs(voxel.min()) < 0.01 and abs(voxel.max() - 1) < 0.01
# Out:
# Averaging frames...: 100%|██████████| 300/300 [00:09<00:00, 30.86it/s]

# %%
FRAME = 100
imshow(
    {
        "Raw": voxel_xs["raw"][FRAME],
        "DeepCAD": voxel_xs["deep_cad"][FRAME],
        "FFT-fused": voxel_xs["fft"][FRAME],
        "Pseudo-GT": voxel_y[FRAME],
    },
    size=5,
    zoom=3.0
)

# %%
psnrs = {k: psnr3d(voxel_y, v) for k, v in tqdm(voxel_xs.items())}

for k, psnr in psnrs.items():
    cprint(f"PSNR with {k} =", f"green:{psnr:.2f}dB")
# Out:
# 100%|██████████| 3/3 [00:00<00:00,  5.21it/s]
# PSNR with raw = 14.99dB
# PSNR with deep_cad = 28.83dB
# PSNR with fft = 29.94dB

# %%
STEP=16
ssims = {k: ssim3D(voxel_y[::STEP], v[::STEP]) for k, v in tqdm(voxel_xs.items())}

for k, ssim in ssims.items():
    cprint(f"PSNR with {k} =", f"green:{ssim:.2f}")
# Out:
# 100%|██████████| 3/3 [00:24<00:00,  8.12s/it]
# PSNR with raw = 0.17
# PSNR with deep_cad = 0.83
# PSNR with fft = 0.91

# %% [markdown]
# SSIM3D comparison with different step values (higher `step` means faster computation, but more coarse SSIM3D):
# |STEP|Raw|Deep_cad|FFT|
# |:--:|--|--|--|
# |`64`|0.31|0.95|0.97|
# |`32`|0.21|0.87|0.93|
# |`20`|0.19|0.84|0.92|
# |`16`|0.17|0.83|0.91|
# |`8`|0.15|0.82|0.92|
# |`4`|0.15|0.82|0.93|

# %%
df = pd.DataFrame({
    "PSNR (dB)": psnrs,
    "SSIM3D": ssims
})
fig, ax1 = plt.subplots(figsize=(9,4))

# plot PSNR
df["PSNR (dB)"].plot(kind="barh", ax=ax1, color="tab:blue", position=1, width=0.4, label="PSNR (dB)")
ax1.set_xlim(0,35)
ax1.set_xticks(range(0,36,7))
ax1.set_xlabel("PSNR (dB)")

ax2 = ax1.twiny()
df["SSIM3D"].plot(kind="barh", ax=ax2, color="tab:orange", position=0, width=0.4, label="SSIM3D")
ax2.set_xlim(0,1)
ax2.set_xlabel("SSIM3D")

ax1.set_yticks(range(len(df)))
ax1.set_yticklabels(df.index)
ax1.set_title("Comparison of Denoising Methods")

h1,l1 = ax1.get_legend_handles_labels()
h2,l2 = ax2.get_legend_handles_labels()
ax1.legend(h1+h2, l1+l2, loc="lower right")

plt.tight_layout()
plt.show()
